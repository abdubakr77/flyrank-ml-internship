# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdubakr77/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane: Refresh / Content Opportunity Scoring**
#
# I'm choosing this lane because it builds directly on Notebook 2, where I already compared a hand-written rule (stale x visible pages) against a depth-2 decision tree using Precision@50. This lane extends that same problem into a full ranked review queue with reason codes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Question:** Which pages should the content team review first this week, based on signals we can observe before the decision (staleness, visibility, ranking position, CTR)?
#
# **Unit of analysis:** one content page.
#
# **The decision this improves:** which pages a reviewer opens first out of hundreds of candidates.
#
# **The action:** a content editor rewrites or updates the flagged page.
#
# **Cost of a wrong call:** if the queue flags a page that isn't really declining, the editor wastes limited review time on the wrong page. If it misses a real decliner, that page keeps losing search visibility unnoticed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Loading the starter dataset and checking three real numbers that support this lane.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

declining = (df["trend_direction"] == "down").sum()
total = len(df)
print(f"Declining pages: {declining} out of {total} ({declining/total:.1%})")

stale_and_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Pages that are stale AND still visible: {stale_and_visible}")

print(f"Hand rule Precision@50 (from Notebook 2): 0.740")
# Out:
# Declining pages: 16262 out of 30000 (54.2%)
# Pages that are stale AND still visible: 17
# Hand rule Precision@50 (from Notebook 2): 0.740

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **I can claim:** staleness combined with continued visibility is a reasonable starting signal for prioritizing review, since it already beats a random ordering in Notebook 2.
#
# **I cannot claim:** that refreshing these pages will cause traffic recovery, or that this rule generalizes beyond the starter dataset without testing on the full warehouse release.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
